# %%
# !pip install selenium
# !pip install bs4
# Out:
# ...
#      |████████████████████████████████| 6.5 MB 4.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 384 kB 14.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 60 kB 6.0 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 58 kB 12.8 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/sherlockieee/.pyenv/versions/3.9.9/bin/python3.9 -m pip install --upgrade pip' command.
# ...
#      |████████████████████████████████| 142 kB 1.2 MB/s eta 0:00:01
# ...
# Using legacy 'setup.py install' for bs4, since package 'wheel' is not installed.
# ...
#     Running setup.py install for bs4 ... done
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/sherlockieee/.pyenv/versions/3.9.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import selenium.webdriver.support.ui as ui
import time

from bs4 import BeautifulSoup

chrome_options = webdriver.ChromeOptions()


# initialize a webdriver instance
#driver = webdriver.Chrome(options=chrome_options)

# initialize a webdriver instance
driver = webdriver.Chrome(options=chrome_options)

# navigate to the login page
# driver.get("https://forum.minerva.edu/?next=/app/login")


# wait = ui.WebDriverWait(driver, 120)
# wait.until(lambda driver: driver.current_url == "https://forum.minerva.edu/app")

# # navigate to the page you want to scrape
# driver.get("https://forum.minerva.edu/app/outcome-index?tab=hcs")

# # get the HTML source code of the page
# html = driver.page_source
# # use BeautifulSoup to parse the HTML and extract the data you need
# soup = BeautifulSoup(html, "html.parser")
# print(soup)
# data = soup.find_all("a", class_="hash-link")

# print(data)

# # close the webdriver instance
# driver.quit()


def login():
    
    main_window_handle = None
    while not main_window_handle:
        main_window_handle = driver.current_window_handle
    time.sleep(5)
    login_button = driver.find_element(by=By.XPATH, value="//button[1]")
    login_button.click()

    signin_window_handle = None
    while not signin_window_handle:
        for handle in driver.window_handles:
            if handle != main_window_handle:
                signin_window_handle = handle
                break

    driver.switch_to.window(signin_window_handle)
    

    if mail_address == "fff":
        mail_address = input("E-mail: ")
        try_save_email = True

    try:

        driver.find_element_by_id("identifierId").send_keys(mail_address)
        driver.find_element_by_id("identifierNext").click()
        wait = ui.WebDriverWait(driver, 120)
        element = wait.until(lambda driver: driver.current_url == "https://forum.minerva.edu/app")
        
            
        if password == "fff":
            password = input("Password: ")
            try_save_password = True
        try:
            #print("test")
            time.sleep(1)
            driver.find_element_by_name("password").send_keys(password)
            #print("here")
            driver.find_element_by_id("passwordNext").click()
           

        except:
            print("Wrong password")
        
    except:
        print("Wrong email")
    
    time.sleep(10)
    driver.switch_to.window(main_window_handle)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    print(soup)
    hcs = soup.find('a',class_='hash-link')
    if hcs == None:
        print("Login failed")
    else:
        print("HCs", hcs)

login()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/4t/s7h_bc712jxdysthkfx2q_v00000gn/T/ipykernel_1544/2010647175.py in <module>
#      98         print("HCs", hcs)
#      99
# --> 100 login()
#
# /var/folders/4t/s7h_bc712jxdysthkfx2q_v00000gn/T/ipykernel_1544/2010647175.py in login()
#      45         main_window_handle = driver.current_window_handle
#      46     time.sleep(5)
# ---> 47     login_button = driver.find_element(by=By.XPATH, value="//button[1]")
#      48     login_button.click()
#      49
#
# ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
# ...
